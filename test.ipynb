# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

# %%
IMAGE_PATH= "/Users/nithinvadekkapat/work/cone_inspect/color_segment/data/test0/92_vl.png"
PATTERN_ID = "001"
OUTPUT_DIRECTORY = "/Users/nithinvadekkapat/work/cone_inspect/color_segment/templates"

# %%
img = cv2.imread(IMAGE_PATH)

# %%
from utils import find_radius

# %%
cropped_img,center, radius  = find_radius.find_radius(img)

# %%
plt.imshow(cropped_img)
plt.show()

# %%
from utils import bilateral_filter
filtered_img = bilateral_filter.apply_bilateral_filter(cropped_img, d=9, sigma_color=30, sigma_space=9)

# %%
plt.imshow(filtered_img)
plt.show()

# %%
from utils import convert_lab
lab_img = convert_lab.convert_to_lab(filtered_img)

# %%
plt.imshow(lab_img)
plt.show()

# %%
radius
# Out:
# 122

# %%
plt.imshow(polar_img)
plt.show()
